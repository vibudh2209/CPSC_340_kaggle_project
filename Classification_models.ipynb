# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
import time, random
import multiprocessing
from multiprocessing import Pool
from contextlib import closing
from functools import partial
from sklearn.metrics import precision_score,recall_score,accuracy_score
from scipy.stats import mode

# %%
t=time.time()
X_valid = pd.read_csv('X_valid.csv',sep=',',header=0).values
y_valid = pd.read_csv('y_valid.csv',sep=',',header=None).values
X_train = pd.read_csv('X_train.csv',sep=',',header=0).values
y_train = pd.read_csv('y_train.csv',sep=',',header=0).values
print(time.time()-t)
# Out:
# 27.152809381484985

# %%
def rf_classifier(feat):
    t=time.time()
    max_features,n_estimators = feat
    X_train = pd.read_csv('X_train.csv',sep=',',header=0).values
    y_train = pd.read_csv('y_train.csv',sep=',',header=0).values
    X_pos = np.array([X_train[i,:] for i in range(X_train.shape[0]) if (y_train[i]==1)])
    y_pos = y_train[y_train==1]
    X_neg = np.array([X_train[i,:] for i in range(X_train.shape[0]) if (y_train[i]==0)])
    y_neg = y_train[y_train==0]
    over_samp_ct = 100000
    _,d = X_pos.shape
    n_pos_train = X_pos.shape[0]
    n_neg_train = X_neg.shape[0]
    Over_under_X_train = np.zeros([over_samp_ct*2,d])
    Over_under_y_train = np.zeros([over_samp_ct*2,])
    for i in range(over_samp_ct):
        idx_pos = random.randint(0,n_pos_train-1)
        idx_neg = random.randint(0,n_neg_train-1)
        Over_under_X_train[2*i,:] = X_pos[idx_pos,:]
        Over_under_y_train[2*i] = y_pos[idx_pos]
        Over_under_X_train[2*i+1,:] = X_neg[idx_neg,:]
        Over_under_y_train[2*i+1] = y_neg[idx_neg]
    rf = RandomForestClassifier(n_estimators=n_estimators).fit(Over_under_X_train,Over_under_y_train)
    X_pos = []
    y_pos = []
    X_neg = []
    y_neg = []
    Over_under_X_train = []
    Over_under_y_train = []
    X_valid = pd.read_csv('X_valid.csv',sep=',',header=0).values
    y_valid = pd.read_csv('y_valid.csv',sep=',',header=None).values
    train_pred = rf.predict(X_train)
    valid_pred = rf.predict(X_valid)
    X_train = []
    X_valid = []
    print(time.time()-t)
    with open('hyperparameter_file.csv','a') as ref:
        ref.write(str(max_features)+','+str(n_estimators)+','+str(precision_score(y_train,train_pred))+','+str(recall_score(y_train,train_pred))+','+str(precision_score(y_valid,valid_pred))+','+str(recall_score(y_valid,valid_pred))+'\n')

# %%
hy_params = []
for n_estimators in [100,200,300,400,500,600,700,800,900,1000]:
    for max_features in np.linspace(10,50,41):
        hy_params.append([max_features,n_estimators])

# %%
t=time.time()
rf_classifier(hy_params[0])
print(time.time()-t)
# Out:
# 121.70113325119019
# 122.08692693710327

# %%
t=time.time()
with closing(Pool(24)) as pool:
    pool.map(rf_classifier,hy_params)
print(time.time()-t)
# Out:
# 143.4599311351776
# 144.27813076972961
# 144.3105251789093
# 144.47761011123657
# 144.70588898658752
# 145.21825313568115
# 149.22946095466614
# 150.27774930000305
# 150.4424033164978
# 242.1206133365631
# 244.02271437644958
# 246.34697198867798
# 253.01286482810974
# 254.38182067871094
# 256.68698048591614
# 258.7305941581726
# 270.52531576156616
# 135.09341049194336
# 136.45545554161072
# 138.1447892189026
# 137.99832248687744
# 138.47131657600403
# 141.5401952266693
# 143.80725622177124
# 143.07223677635193
# 350.2600483894348
# 352.1334080696106
# 355.98028230667114
# 356.00201535224915
# 356.31116008758545
# 357.072482585907
# 360.5362012386322
# Process ForkPoolWorker-20:
# Process ForkPoolWorker-14:
# Process ForkPoolWorker-4:
# Process ForkPoolWorker-21:
# Process ForkPoolWorker-19:
# Process ForkPoolWorker-9:
# Process ForkPoolWorker-24:
# Process ForkPoolWorker-18:
# Process ForkPoolWorker-22:
# Process ForkPoolWorker-23:
# Process ForkPoolWorker-7:
# Process ForkPoolWorker-8:
# Process ForkPoolWorker-12:
# Process ForkPoolWorker-17:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.5.4/lib/python3.5/multiprocessing/process.py", line 252, in _bootstrap
#     self.run()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.5.4/lib/python3.5/multiprocessing/process.py", line 252, in _bootstrap
#     self.run()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.5.4/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.5.4/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.5.4/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.5.4/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.5.4/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "<ipython-input-3-54b01af67e89>", line 8, in rf_classifier
#     X_neg = np.array([X_train[i,:] for i in range(X_train.shape[0]) if (y_train[i]==0)])
#   File "<ipython-input-3-54b01af67e89>", line 8, in <listcomp>
#     X_neg = np.array([X_train[i,:] for i in range(X_train.shape[0]) if (y_train[i]==0)])
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.5.4/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
# KeyboardInterrupt
#   File "<ipython-input-3-54b01af67e89>", line 6, in rf_classifier
#     X_pos = np.array([X_train[i,:] for i in range(X_train.shape[0]) if (y_train[i]==1)])
#   File "<ipython-input-3-54b01af67e89>", line 6, in <listcomp>
#     X_pos = np.array([X_train[i,:] for i in range(X_train.shape[0]) if (y_train[i]==1)])
# KeyboardInterrupt
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.5.4/lib/python3.5/multiprocessing/process.py", line 252, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.5.4/lib/python3.5/multiprocessing/process.py", line 252, in _bootstrap
#     self.run()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.5.4/lib/python3.5/multiprocessing/process.py", line 252, in _bootstrap
#     self.run()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.5.4/lib/python3.5/multiprocessing/process.py", line 252, in _bootstrap
#     self.run()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.5.4/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.5.4/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.5.4/lib/python3.5/multiprocessing/process.py", line 252, in _bootstrap
#     self.run()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.5.4/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.5.4/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.5.4/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.5.4/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.5.4/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.5.4/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.5.4/lib/python3.5/multiprocessing/process.py", line 252, in _bootstrap
#     self.run()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.5.4/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.5.4/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.5.4/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.5.4/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
# Traceback (most recent call last):
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.5.4/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.5.4/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-3-54b01af67e89>", line 4, in rf_classifier
#     X_train = pd.read_csv('X_train.csv',sep=',',header=0).values
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "<ipython-input-3-54b01af67e89>", line 4, in rf_classifier
#     X_train = pd.read_csv('X_train.csv',sep=',',header=0).values
#   File "<ipython-input-3-54b01af67e89>", line 4, in rf_classifier
#     X_train = pd.read_csv('X_train.csv',sep=',',header=0).values
# Traceback (most recent call last):
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.5.4/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.5.4/lib/python3.5/multiprocessing/process.py", line 252, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.5.4/lib/python3.5/multiprocessing/process.py", line 252, in _bootstrap
#     self.run()
#   File "<ipython-input-3-54b01af67e89>", line 4, in rf_classifier
#     X_train = pd.read_csv('X_train.csv',sep=',',header=0).values
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/pandas/io/parsers.py", line 678, in parser_f
#     return _read(filepath_or_buffer, kwds)
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/pandas/io/parsers.py", line 678, in parser_f
#     return _read(filepath_or_buffer, kwds)
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.5.4/lib/python3.5/multiprocessing/process.py", line 252, in _bootstrap
#     self.run()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.5.4/lib/python3.5/multiprocessing/process.py", line 252, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.5.4/lib/python3.5/multiprocessing/process.py", line 252, in _bootstrap
#     self.run()
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/pandas/io/parsers.py", line 446, in _read
#     data = parser.read(nrows)
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.5.4/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.5.4/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/pandas/io/parsers.py", line 446, in _read
#     data = parser.read(nrows)
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.5.4/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/pandas/io/parsers.py", line 678, in parser_f
#     return _read(filepath_or_buffer, kwds)
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.5.4/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.5.4/lib/python3.5/multiprocessing/process.py", line 252, in _bootstrap
#     self.run()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.5.4/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.5.4/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/pandas/io/parsers.py", line 1036, in read
#     ret = self._engine.read(nrows)
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.5.4/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.5.4/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/pandas/io/parsers.py", line 1036, in read
#     ret = self._engine.read(nrows)
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.5.4/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/pandas/io/parsers.py", line 446, in _read
#     data = parser.read(nrows)
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.5.4/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/pandas/io/parsers.py", line 678, in parser_f
#     return _read(filepath_or_buffer, kwds)
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.5.4/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.5.4/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.5.4/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.5.4/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/pandas/io/parsers.py", line 1848, in read
#     data = self._reader.read(nrows)
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/pandas/io/parsers.py", line 1848, in read
#     data = self._reader.read(nrows)
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.5.4/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.5.4/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/pandas/io/parsers.py", line 446, in _read
#     data = parser.read(nrows)
#   File "<ipython-input-3-54b01af67e89>", line 33, in rf_classifier
#     valid_pred = rf.predict(X_valid)
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/pandas/io/parsers.py", line 1036, in read
#     ret = self._engine.read(nrows)
#   File "<ipython-input-3-54b01af67e89>", line 23, in rf_classifier
#     rf = RandomForestClassifier(n_estimators=n_estimators).fit(Over_under_X_train,Over_under_y_train)
#   File "pandas/_libs/parsers.pyx", line 876, in pandas._libs.parsers.TextReader.read
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.5.4/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "<ipython-input-3-54b01af67e89>", line 32, in rf_classifier
#     train_pred = rf.predict(X_train)
#   File "pandas/_libs/parsers.pyx", line 876, in pandas._libs.parsers.TextReader.read
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.5.4/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/pandas/io/parsers.py", line 1036, in read
#     ret = self._engine.read(nrows)
#   File "<ipython-input-3-54b01af67e89>", line 32, in rf_classifier
#     train_pred = rf.predict(X_train)
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/ensemble/forest.py", line 545, in predict
#     proba = self.predict_proba(X)
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/ensemble/forest.py", line 335, in fit
#     for i, t in enumerate(trees))
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/pandas/io/parsers.py", line 1848, in read
#     data = self._reader.read(nrows)
#   File "pandas/_libs/parsers.pyx", line 891, in pandas._libs.parsers.TextReader._read_low_memory
#   File "<ipython-input-3-54b01af67e89>", line 23, in rf_classifier
#     rf = RandomForestClassifier(n_estimators=n_estimators).fit(Over_under_X_train,Over_under_y_train)
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/ensemble/forest.py", line 545, in predict
#     proba = self.predict_proba(X)
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/pandas/io/parsers.py", line 1848, in read
#     data = self._reader.read(nrows)
#   File "pandas/_libs/parsers.pyx", line 891, in pandas._libs.parsers.TextReader._read_low_memory
#   File "<ipython-input-3-54b01af67e89>", line 23, in rf_classifier
#     rf = RandomForestClassifier(n_estimators=n_estimators).fit(Over_under_X_train,Over_under_y_train)
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/ensemble/forest.py", line 597, in predict_proba
#     for e in self.estimators_)
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/ensemble/forest.py", line 545, in predict
#     proba = self.predict_proba(X)
#   File "pandas/_libs/parsers.pyx", line 876, in pandas._libs.parsers.TextReader.read
#   File "pandas/_libs/parsers.pyx", line 968, in pandas._libs.parsers.TextReader._read_rows
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/ensemble/forest.py", line 597, in predict_proba
#     for e in self.estimators_)
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py", line 986, in __call__
#     while self.dispatch_one_batch(iterator):
#   File "pandas/_libs/parsers.pyx", line 876, in pandas._libs.parsers.TextReader.read
#   File "pandas/_libs/parsers.pyx", line 968, in pandas._libs.parsers.TextReader._read_rows
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/ensemble/forest.py", line 335, in fit
#     for i, t in enumerate(trees))
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/ensemble/forest.py", line 597, in predict_proba
#     for e in self.estimators_)
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/ensemble/forest.py", line 335, in fit
#     for i, t in enumerate(trees))
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py", line 986, in __call__
#     while self.dispatch_one_batch(iterator):
#   File "pandas/_libs/parsers.pyx", line 891, in pandas._libs.parsers.TextReader._read_low_memory
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py", line 986, in __call__
#     while self.dispatch_one_batch(iterator):
#   File "pandas/_libs/parsers.pyx", line 1094, in pandas._libs.parsers.TextReader._convert_column_data
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py", line 825, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py", line 986, in __call__
#     while self.dispatch_one_batch(iterator):
#   File "pandas/_libs/parsers.pyx", line 891, in pandas._libs.parsers.TextReader._read_low_memory
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py", line 986, in __call__
#     while self.dispatch_one_batch(iterator):
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py", line 986, in __call__
#     while self.dispatch_one_batch(iterator):
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py", line 825, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "pandas/_libs/parsers.pyx", line 1094, in pandas._libs.parsers.TextReader._convert_column_data
#   File "pandas/_libs/parsers.pyx", line 968, in pandas._libs.parsers.TextReader._read_rows
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py", line 825, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "pandas/_libs/parsers.pyx", line 1134, in pandas._libs.parsers.TextReader._convert_tokens
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.5.4/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py", line 825, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py", line 782, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py", line 825, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "pandas/_libs/parsers.pyx", line 968, in pandas._libs.parsers.TextReader._read_rows
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py", line 825, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py", line 782, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "pandas/_libs/parsers.pyx", line 1134, in pandas._libs.parsers.TextReader._convert_tokens
#   File "pandas/_libs/parsers.pyx", line 1094, in pandas._libs.parsers.TextReader._convert_column_data
#   File "pandas/_libs/parsers.pyx", line 1180, in pandas._libs.parsers.TextReader._convert_with_dtype
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py", line 782, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py", line 782, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py", line 782, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/_parallel_backends.py", line 182, in apply_async
#     result = ImmediateResult(func)
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py", line 782, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/_parallel_backends.py", line 182, in apply_async
#     result = ImmediateResult(func)
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/tree/tree.py", line 831, in predict_proba
#     proba = self.tree_.predict(X)
#   File "pandas/_libs/parsers.pyx", line 1094, in pandas._libs.parsers.TextReader._convert_column_data
#   File "pandas/_libs/parsers.pyx", line 1134, in pandas._libs.parsers.TextReader._convert_tokens
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/pandas/core/dtypes/common.py", line 855, in is_integer_dtype
#     not issubclass(tipo, (np.datetime64, np.timedelta64)))
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.5.4/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "pandas/_libs/parsers.pyx", line 1180, in pandas._libs.parsers.TextReader._convert_with_dtype
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/_parallel_backends.py", line 182, in apply_async
#     result = ImmediateResult(func)
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/_parallel_backends.py", line 182, in apply_async
#     result = ImmediateResult(func)
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/_parallel_backends.py", line 182, in apply_async
#     result = ImmediateResult(func)
#   File "pandas/_libs/parsers.pyx", line 1134, in pandas._libs.parsers.TextReader._convert_tokens
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/_parallel_backends.py", line 545, in __init__
#     self.results = batch()
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/_parallel_backends.py", line 545, in __init__
#     self.results = batch()
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/_parallel_backends.py", line 182, in apply_async
#     result = ImmediateResult(func)
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.5.4/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/_parallel_backends.py", line 545, in __init__
#     self.results = batch()
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/_parallel_backends.py", line 545, in __init__
#     self.results = batch()
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py", line 261, in __call__
#     for func, args, kwargs in self.items]
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/pandas/core/dtypes/common.py", line 811, in is_integer_dtype
#     def is_integer_dtype(arr_or_dtype):
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py", line 261, in __call__
#     for func, args, kwargs in self.items]
#   File "<ipython-input-3-54b01af67e89>", line 30, in rf_classifier
#     X_valid = pd.read_csv('X_valid.csv',sep=',',header=0).values
#   File "pandas/_libs/parsers.pyx", line 1180, in pandas._libs.parsers.TextReader._convert_with_dtype
#   File "pandas/_libs/parsers.pyx", line 1180, in pandas._libs.parsers.TextReader._convert_with_dtype
# KeyboardInterrupt
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/_parallel_backends.py", line 545, in __init__
#     self.results = batch()
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py", line 261, in __call__
#     for func, args, kwargs in self.items]
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py", line 261, in <listcomp>
#     for func, args, kwargs in self.items]
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py", line 261, in __call__
#     for func, args, kwargs in self.items]
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py", line 261, in <listcomp>
#     for func, args, kwargs in self.items]
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/pandas/io/parsers.py", line 678, in parser_f
#     return _read(filepath_or_buffer, kwds)
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/pandas/core/dtypes/common.py", line 811, in is_integer_dtype
#     def is_integer_dtype(arr_or_dtype):
# KeyboardInterrupt
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/pandas/core/dtypes/common.py", line 811, in is_integer_dtype
#     def is_integer_dtype(arr_or_dtype):
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/ensemble/forest.py", line 121, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/ensemble/forest.py", line 391, in _accumulate_prediction
#     prediction = predict(X, check_input=False)
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py", line 261, in __call__
#     for func, args, kwargs in self.items]
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/pandas/io/parsers.py", line 446, in _read
#     data = parser.read(nrows)
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py", line 261, in <listcomp>
#     for func, args, kwargs in self.items]
# KeyboardInterrupt
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py", line 261, in <listcomp>
#     for func, args, kwargs in self.items]
# KeyboardInterrupt
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/tree/tree.py", line 799, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/pandas/io/parsers.py", line 1036, in read
#     ret = self._engine.read(nrows)
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/tree/tree.py", line 831, in predict_proba
#     proba = self.tree_.predict(X)
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/ensemble/forest.py", line 121, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/ensemble/forest.py", line 391, in _accumulate_prediction
#     prediction = predict(X, check_input=False)
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/tree/tree.py", line 365, in fit
#     builder.build(self.tree_, X, y, sample_weight, X_idx_sorted)
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py", line 261, in <listcomp>
#     for func, args, kwargs in self.items]
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/pandas/io/parsers.py", line 1848, in read
#     data = self._reader.read(nrows)
# KeyboardInterrupt
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/ensemble/forest.py", line 121, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
# KeyboardInterrupt
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/tree/tree.py", line 799, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "pandas/_libs/parsers.pyx", line 876, in pandas._libs.parsers.TextReader.read
#   File "pandas/_libs/parsers.pyx", line 891, in pandas._libs.parsers.TextReader._read_low_memory
#   File "pandas/_libs/parsers.pyx", line 968, in pandas._libs.parsers.TextReader._read_rows
#   File "pandas/_libs/parsers.pyx", line 1094, in pandas._libs.parsers.TextReader._convert_column_data
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/_parallel_backends.py", line 545, in __init__
#     self.results = batch()
#   File "pandas/_libs/parsers.pyx", line 1134, in pandas._libs.parsers.TextReader._convert_tokens
#   File "<ipython-input-3-54b01af67e89>", line 4, in rf_classifier
#     X_train = pd.read_csv('X_train.csv',sep=',',header=0).values
#   File "pandas/_libs/parsers.pyx", line 1180, in pandas._libs.parsers.TextReader._convert_with_dtype
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/pandas/io/parsers.py", line 678, in parser_f
#     return _read(filepath_or_buffer, kwds)
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py", line 261, in __call__
#     for func, args, kwargs in self.items]
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/pandas/core/dtypes/common.py", line 811, in is_integer_dtype
#     def is_integer_dtype(arr_or_dtype):
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py", line 261, in <listcomp>
#     for func, args, kwargs in self.items]
# KeyboardInterrupt
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/ensemble/forest.py", line 391, in _accumulate_prediction
#     prediction = predict(X, check_input=False)
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/tree/tree.py", line 831, in predict_proba
#     proba = self.tree_.predict(X)
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/tree/tree.py", line 152, in fit
#     return_inverse=True)
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/pandas/io/parsers.py", line 446, in _read
#     data = parser.read(nrows)
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/pandas/io/parsers.py", line 1036, in read
#     ret = self._engine.read(nrows)
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/pandas/io/parsers.py", line 1848, in read
#     data = self._reader.read(nrows)
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/tree/tree.py", line 799, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/numpy/lib/arraysetops.py", line 233, in unique
#     ret = _unique1d(ar, return_index, return_inverse, return_counts)
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/tree/tree.py", line 365, in fit
#     builder.build(self.tree_, X, y, sample_weight, X_idx_sorted)
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/numpy/lib/arraysetops.py", line 293, in _unique1d
#     inv_idx[perm] = imask
#   File "pandas/_libs/parsers.pyx", line 876, in pandas._libs.parsers.TextReader.read
# Process ForkPoolWorker-1:
# KeyboardInterrupt
# KeyboardInterrupt
#   File "pandas/_libs/parsers.pyx", line 891, in pandas._libs.parsers.TextReader._read_low_memory
#   File "pandas/_libs/parsers.pyx", line 968, in pandas._libs.parsers.TextReader._read_rows
#   File "pandas/_libs/parsers.pyx", line 1094, in pandas._libs.parsers.TextReader._convert_column_data
#   File "pandas/_libs/parsers.pyx", line 1134, in pandas._libs.parsers.TextReader._convert_tokens
#   File "pandas/_libs/parsers.pyx", line 1180, in pandas._libs.parsers.TextReader._convert_with_dtype
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/pandas/core/dtypes/common.py", line 811, in is_integer_dtype
#     def is_integer_dtype(arr_or_dtype):
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.5.4/lib/python3.5/multiprocessing/process.py", line 252, in _bootstrap
#     self.run()
# Process ForkPoolWorker-5:
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.5.4/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.5.4/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.5.4/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
# Process ForkPoolWorker-16:
#   File "<ipython-input-3-54b01af67e89>", line 32, in rf_classifier
#     train_pred = rf.predict(X_train)
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.5.4/lib/python3.5/multiprocessing/process.py", line 252, in _bootstrap
#     self.run()
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/ensemble/forest.py", line 545, in predict
#     proba = self.predict_proba(X)
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.5.4/lib/python3.5/multiprocessing/process.py", line 252, in _bootstrap
#     self.run()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.5.4/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.5.4/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.5.4/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/ensemble/forest.py", line 597, in predict_proba
#     for e in self.estimators_)
#   File "<ipython-input-3-54b01af67e89>", line 23, in rf_classifier
#     rf = RandomForestClassifier(n_estimators=n_estimators).fit(Over_under_X_train,Over_under_y_train)
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.5.4/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py", line 986, in __call__
#     while self.dispatch_one_batch(iterator):
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/ensemble/forest.py", line 335, in fit
#     for i, t in enumerate(trees))
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.5.4/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py", line 986, in __call__
#     while self.dispatch_one_batch(iterator):
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py", line 825, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py", line 782, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.5.4/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
# Process ForkPoolWorker-11:
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py", line 825, in dispatch_one_batch
#     self._dispatch(tasks)
# Traceback (most recent call last):
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.5.4/lib/python3.5/multiprocessing/process.py", line 252, in _bootstrap
#     self.run()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.5.4/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-3-54b01af67e89>", line 32, in rf_classifier
#     train_pred = rf.predict(X_train)
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.5.4/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/_parallel_backends.py", line 182, in apply_async
#     result = ImmediateResult(func)
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/ensemble/forest.py", line 545, in predict
#     proba = self.predict_proba(X)
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/_parallel_backends.py", line 545, in __init__
#     self.results = batch()
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/ensemble/forest.py", line 597, in predict_proba
#     for e in self.estimators_)
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py", line 782, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py", line 986, in __call__
#     while self.dispatch_one_batch(iterator):
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/_parallel_backends.py", line 182, in apply_async
#     result = ImmediateResult(func)
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.5.4/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py", line 261, in __call__
#     for func, args, kwargs in self.items]
#   File "<ipython-input-3-54b01af67e89>", line 23, in rf_classifier
#     rf = RandomForestClassifier(n_estimators=n_estimators).fit(Over_under_X_train,Over_under_y_train)
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/_parallel_backends.py", line 545, in __init__
#     self.results = batch()
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/ensemble/forest.py", line 335, in fit
#     for i, t in enumerate(trees))
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py", line 261, in <listcomp>
#     for func, args, kwargs in self.items]
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py", line 261, in __call__
#     for func, args, kwargs in self.items]
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py", line 986, in __call__
#     while self.dispatch_one_batch(iterator):
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/ensemble/forest.py", line 391, in _accumulate_prediction
#     prediction = predict(X, check_input=False)
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py", line 261, in <listcomp>
#     for func, args, kwargs in self.items]
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/ensemble/forest.py", line 121, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/tree/tree.py", line 799, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/tree/tree.py", line 831, in predict_proba
#     proba = self.tree_.predict(X)
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py", line 825, in dispatch_one_batch
#     self._dispatch(tasks)
# KeyboardInterrupt
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/tree/tree.py", line 365, in fit
#     builder.build(self.tree_, X, y, sample_weight, X_idx_sorted)
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py", line 825, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py", line 782, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/tree/tree.py", line 365, in fit
#     builder.build(self.tree_, X, y, sample_weight, X_idx_sorted)
# KeyboardInterrupt
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py", line 782, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/_parallel_backends.py", line 182, in apply_async
#     result = ImmediateResult(func)
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/_parallel_backends.py", line 545, in __init__
#     self.results = batch()
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py", line 261, in __call__
#     for func, args, kwargs in self.items]
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py", line 261, in <listcomp>
#     for func, args, kwargs in self.items]
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/ensemble/forest.py", line 121, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/tree/tree.py", line 799, in fit
#     X_idx_sorted=X_idx_sorted)
# KeyboardInterrupt
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/_parallel_backends.py", line 182, in apply_async
#     result = ImmediateResult(func)
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/_parallel_backends.py", line 545, in __init__
#     self.results = batch()
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py", line 261, in __call__
#     for func, args, kwargs in self.items]
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py", line 261, in <listcomp>
#     for func, args, kwargs in self.items]
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/ensemble/forest.py", line 391, in _accumulate_prediction
#     prediction = predict(X, check_input=False)
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/tree/tree.py", line 831, in predict_proba
#     proba = self.tree_.predict(X)
# KeyboardInterrupt
# Process ForkPoolWorker-13:
# Process ForkPoolWorker-15:
# Process ForkPoolWorker-3:
# Traceback (most recent call last):
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.5.4/lib/python3.5/multiprocessing/process.py", line 252, in _bootstrap
#     self.run()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.5.4/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.5.4/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.5.4/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
# Process ForkPoolWorker-10:
#   File "<ipython-input-3-54b01af67e89>", line 23, in rf_classifier
#     rf = RandomForestClassifier(n_estimators=n_estimators).fit(Over_under_X_train,Over_under_y_train)
# Process ForkPoolWorker-6:
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/ensemble/forest.py", line 335, in fit
#     for i, t in enumerate(trees))
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.5.4/lib/python3.5/multiprocessing/process.py", line 252, in _bootstrap
#     self.run()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.5.4/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.5.4/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.5.4/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "<ipython-input-3-54b01af67e89>", line 23, in rf_classifier
#     rf = RandomForestClassifier(n_estimators=n_estimators).fit(Over_under_X_train,Over_under_y_train)
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/ensemble/forest.py", line 335, in fit
#     for i, t in enumerate(trees))
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py", line 986, in __call__
#     while self.dispatch_one_batch(iterator):
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py", line 825, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py", line 986, in __call__
#     while self.dispatch_one_batch(iterator):
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py", line 782, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/_parallel_backends.py", line 182, in apply_async
#     result = ImmediateResult(func)
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/_parallel_backends.py", line 545, in __init__
#     self.results = batch()
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py", line 261, in __call__
#     for func, args, kwargs in self.items]
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py", line 261, in <listcomp>
#     for func, args, kwargs in self.items]
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/ensemble/forest.py", line 121, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/tree/tree.py", line 799, in fit
#     X_idx_sorted=X_idx_sorted)
# Traceback (most recent call last):
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.5.4/lib/python3.5/multiprocessing/process.py", line 252, in _bootstrap
#     self.run()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.5.4/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.5.4/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
# Process ForkPoolWorker-2:
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/tree/tree.py", line 365, in fit
#     builder.build(self.tree_, X, y, sample_weight, X_idx_sorted)
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.5.4/lib/python3.5/multiprocessing/process.py", line 252, in _bootstrap
#     self.run()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.5.4/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.5.4/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.5.4/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "<ipython-input-3-54b01af67e89>", line 23, in rf_classifier
#     rf = RandomForestClassifier(n_estimators=n_estimators).fit(Over_under_X_train,Over_under_y_train)
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/ensemble/forest.py", line 335, in fit
#     for i, t in enumerate(trees))
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py", line 986, in __call__
#     while self.dispatch_one_batch(iterator):
# Traceback (most recent call last):
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py", line 825, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.5.4/lib/python3.5/multiprocessing/process.py", line 252, in _bootstrap
#     self.run()
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py", line 782, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/_parallel_backends.py", line 182, in apply_async
#     result = ImmediateResult(func)
# Traceback (most recent call last):
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/_parallel_backends.py", line 545, in __init__
#     self.results = batch()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.5.4/lib/python3.5/multiprocessing/process.py", line 252, in _bootstrap
#     self.run()
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py", line 261, in __call__
#     for func, args, kwargs in self.items]
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.5.4/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py", line 261, in <listcomp>
#     for func, args, kwargs in self.items]
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.5.4/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/ensemble/forest.py", line 121, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "<ipython-input-3-54b01af67e89>", line 23, in rf_classifier
#     rf = RandomForestClassifier(n_estimators=n_estimators).fit(Over_under_X_train,Over_under_y_train)
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/ensemble/forest.py", line 335, in fit
#     for i, t in enumerate(trees))
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/tree/tree.py", line 799, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py", line 986, in __call__
#     while self.dispatch_one_batch(iterator):
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/tree/tree.py", line 365, in fit
#     builder.build(self.tree_, X, y, sample_weight, X_idx_sorted)
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py", line 825, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py", line 782, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py", line 825, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.5.4/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py", line 782, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/_parallel_backends.py", line 182, in apply_async
#     result = ImmediateResult(func)
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/_parallel_backends.py", line 545, in __init__
#     self.results = batch()
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/_parallel_backends.py", line 182, in apply_async
#     result = ImmediateResult(func)
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.5.4/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/_parallel_backends.py", line 545, in __init__
#     self.results = batch()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.5.4/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-3-54b01af67e89>", line 23, in rf_classifier
#     rf = RandomForestClassifier(n_estimators=n_estimators).fit(Over_under_X_train,Over_under_y_train)
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py", line 261, in __call__
#     for func, args, kwargs in self.items]
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/ensemble/forest.py", line 335, in fit
#     for i, t in enumerate(trees))
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py", line 261, in <listcomp>
#     for func, args, kwargs in self.items]
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py", line 986, in __call__
#     while self.dispatch_one_batch(iterator):
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/ensemble/forest.py", line 121, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py", line 825, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.5.4/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py", line 782, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.5.4/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/tree/tree.py", line 799, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "<ipython-input-3-54b01af67e89>", line 23, in rf_classifier
#     rf = RandomForestClassifier(n_estimators=n_estimators).fit(Over_under_X_train,Over_under_y_train)
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/_parallel_backends.py", line 182, in apply_async
#     result = ImmediateResult(func)
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/_parallel_backends.py", line 545, in __init__
#     self.results = batch()
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/tree/tree.py", line 365, in fit
#     builder.build(self.tree_, X, y, sample_weight, X_idx_sorted)
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py", line 261, in __call__
#     for func, args, kwargs in self.items]
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/ensemble/forest.py", line 335, in fit
#     for i, t in enumerate(trees))
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py", line 261, in <listcomp>
#     for func, args, kwargs in self.items]
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py", line 986, in __call__
#     while self.dispatch_one_batch(iterator):
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/ensemble/forest.py", line 121, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py", line 825, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py", line 782, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/tree/tree.py", line 799, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/tree/tree.py", line 365, in fit
#     builder.build(self.tree_, X, y, sample_weight, X_idx_sorted)
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py", line 261, in __call__
#     for func, args, kwargs in self.items]
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/_parallel_backends.py", line 182, in apply_async
#     result = ImmediateResult(func)
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/_parallel_backends.py", line 545, in __init__
#     self.results = batch()
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py", line 261, in __call__
#     for func, args, kwargs in self.items]
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py", line 261, in <listcomp>
#     for func, args, kwargs in self.items]
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py", line 261, in <listcomp>
#     for func, args, kwargs in self.items]
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/ensemble/forest.py", line 121, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/tree/tree.py", line 799, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/tree/tree.py", line 365, in fit
#     builder.build(self.tree_, X, y, sample_weight, X_idx_sorted)
# KeyboardInterrupt
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/ensemble/forest.py", line 121, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/tree/tree.py", line 799, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "/home/vibudh/tensorflow/lib/python3.5/site-packages/sklearn/tree/tree.py", line 365, in fit
#     builder.build(self.tree_, X, y, sample_weight, X_idx_sorted)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-7414fd74ed30> in <module>
#       1 t=time.time()
#       2 with closing(Pool(24)) as pool:
# ----> 3     pool.map(rf_classifier,hy_params)
#       4 print(time.time()-t)
#
# /cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.5.4/lib/python3.5/multiprocessing/pool.py in map(self, func, iterable, chunksize)
#     264         in a list that is returned.
#     265         '''
# --> 266         return self._map_async(func, iterable, mapstar, chunksize).get()
#     267
#     268     def starmap(self, func, iterable, chunksize=None):
#
# /cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.5.4/lib/python3.5/multiprocessing/pool.py in get(self, timeout)
#     636
#     637     def get(self, timeout=None):
# --> 638         self.wait(timeout)
#     639         if not self.ready():
#     640             raise TimeoutError
#
# /cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.5.4/lib/python3.5/multiprocessing/pool.py in wait(self, timeout)
#     633
#     634     def wait(self, timeout=None):
# --> 635         self._event.wait(timeout)
#     636
#     637     def get(self, timeout=None):
#
# /cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.5.4/lib/python3.5/threading.py in wait(self, timeout)
#     547             signaled = self._flag
#     548             if not signaled:
# --> 549                 signaled = self._cond.wait(timeout)
#     550             return signaled
#     551
#
# /cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.5.4/lib/python3.5/threading.py in wait(self, timeout)
#     291         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     292             if timeout is None:
# --> 293                 waiter.acquire()
#     294                 gotit = True
#     295             else:
#
# KeyboardInterrupt:

# %%
'''
val_pred = np.zeros([X_valid.shape[0],multiprocessing.cpu_count()])
tr_pred = np.zeros([X_train.shape[0],multiprocessing.cpu_count()])
for ct,i,j in enumerate(rf_predictions):
    val_pred[:,ct] = i
    tr_pred[:,ct] = j
#print(precision_score(y_train,tr_pred),recall_score(y_train,tr_pred),accuracy_score(y_train,tr_pred))
#print(precision_score(y_valid,val_pred),recall_score(y_valid,val_pred),accuracy_score(y_valid,val_pred))
'''
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-1c276215b298> in <module>()
#       3 for i,pd in enumerate(rf):
#       4     val_pred[:,i] = pd.predict(X_valid)
# ----> 5     tr_pred[:,i] = pd.predict(X_train)
#       6 #print(precision_score(y_train,tr_pred),recall_score(y_train,tr_pred),accuracy_score(y_train,tr_pred))
#       7 #print(precision_score(y_valid,val_pred),recall_score(y_valid,val_pred),accuracy_score(y_valid,val_pred))
#
# ~/.local/easybuild/software/2017/Core/miniconda3/4.3.27/envs/rdkit-env/lib/python3.6/site-packages/sklearn/ensemble/forest.py in predict(self, X)
#     543             The predicted classes.
#     544         """
# --> 545         proba = self.predict_proba(X)
#     546
#     547         if self.n_outputs_ == 1:
#
# ~/.local/easybuild/software/2017/Core/miniconda3/4.3.27/envs/rdkit-env/lib/python3.6/site-packages/sklearn/ensemble/forest.py in predict_proba(self, X)
#     595             delayed(_accumulate_prediction)(e.predict_proba, X, all_proba,
#     596                                             lock)
# --> 597             for e in self.estimators_)
#     598
#     599         for proba in all_proba:
#
# ~/.local/easybuild/software/2017/Core/miniconda3/4.3.27/envs/rdkit-env/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in __call__(self, iterable)
#     984                 self._iterating = self._original_iterator is not None
#     985
# --> 986             while self.dispatch_one_batch(iterator):
#     987                 pass
#     988
#
# ~/.local/easybuild/software/2017/Core/miniconda3/4.3.27/envs/rdkit-env/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     823                 return False
#     824             else:
# --> 825                 self._dispatch(tasks)
#     826                 return True
#     827
#
# ~/.local/easybuild/software/2017/Core/miniconda3/4.3.27/envs/rdkit-env/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in _dispatch(self, batch)
#     780         with self._lock:
#     781             job_idx = len(self._jobs)
# --> 782             job = self._backend.apply_async(batch, callback=cb)
#     783             # A job can complete so quickly than its callback is
#     784             # called before we get here, causing self._jobs to
#
# ~/.local/easybuild/software/2017/Core/miniconda3/4.3.27/envs/rdkit-env/lib/python3.6/site-packages/sklearn/externals/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     180     def apply_async(self, func, callback=None):
#     181         """Schedule a func to be run"""
# --> 182         result = ImmediateResult(func)
#     183         if callback:
#     184             callback(result)
#
# ~/.local/easybuild/software/2017/Core/miniconda3/4.3.27/envs/rdkit-env/lib/python3.6/site-packages/sklearn/externals/joblib/_parallel_backends.py in __init__(self, batch)
#     543         # Don't delay the application, to avoid keeping the input
#     544         # arguments in memory
# --> 545         self.results = batch()
#     546
#     547     def get(self):
#
# ~/.local/easybuild/software/2017/Core/miniconda3/4.3.27/envs/rdkit-env/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in __call__(self)
#     259         with parallel_backend(self._backend):
#     260             return [func(*args, **kwargs)
# --> 261                     for func, args, kwargs in self.items]
#     262
#     263     def __len__(self):
#
# ~/.local/easybuild/software/2017/Core/miniconda3/4.3.27/envs/rdkit-env/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in <listcomp>(.0)
#     259         with parallel_backend(self._backend):
#     260             return [func(*args, **kwargs)
# --> 261                     for func, args, kwargs in self.items]
#     262
#     263     def __len__(self):
#
# ~/.local/easybuild/software/2017/Core/miniconda3/4.3.27/envs/rdkit-env/lib/python3.6/site-packages/sklearn/ensemble/forest.py in _accumulate_prediction(predict, X, out, lock)
#     389     complains that it cannot pickle it when placed there.
#     390     """
# --> 391     prediction = predict(X, check_input=False)
#     392     with lock:
#     393         if len(out) == 1:
#
# ~/.local/easybuild/software/2017/Core/miniconda3/4.3.27/envs/rdkit-env/lib/python3.6/site-packages/sklearn/tree/tree.py in predict_proba(self, X, check_input)
#     833         if self.n_outputs_ == 1:
#     834             proba = proba[:, :self.n_classes_]
# --> 835             normalizer = proba.sum(axis=1)[:, np.newaxis]
#     836             normalizer[normalizer == 0.0] = 1.0
#     837             proba /= normalizer
#
# ~/.local/easybuild/software/2017/Core/miniconda3/4.3.27/envs/rdkit-env/lib/python3.6/site-packages/numpy/core/_methods.py in _sum(a, axis, dtype, out, keepdims, initial)
#      34 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      35          initial=_NoValue):
# ---> 36     return umr_sum(a, axis, dtype, out, keepdims, initial)
#      37
#      38 def _prod(a, axis=None, dtype=None, out=None, keepdims=False,
#
# KeyboardInterrupt:

# %%
'''
val_pred = np.zeros([X_valid.shape[0],len(rf_predictions)])
tr_pred = np.zeros([X_train.shape[0],len(rf_predictions)])
for i in range(len(rf_predictions)):
    val_pred[:,i] = rf_predictions[i][0]
    tr_pred[:,i] = rf_predictions[i][1]

# %%
'''
val_pred_con = mode(val_pred,axis=1).mode
tr_pred_con = mode(tr_pred,axis=1).mode
print(precision_score(y_train,tr_pred_con),recall_score(y_train,tr_pred_con),accuracy_score(y_train,tr_pred_con))
print(precision_score(y_valid,val_pred_con),recall_score(y_valid,val_pred_con),accuracy_score(y_valid,val_pred_con))
'''
# Out:
# 0.29511090862496087 1.0 0.9695618654623387
# 0.24875267284390593 0.9096437880104257 0.9638572883006506
# 0.31085782843431314 1.0 0.9717492797763156
# 0.24970045530793195 0.9052997393570807 0.9641450135009517

# %%
multiprocessing.cpu_count()
# Out:
# 32
